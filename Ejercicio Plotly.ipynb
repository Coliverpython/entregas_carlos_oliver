# %% [markdown]
# # Interactive Visualization Lab - Superstore Dataset
#
# Complete the following set of exercises to solidify your knowledge of interactive visualization using Plotly, Cufflinks, and IPyWidgets.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import plotly as ply
from ipywidgets import widgets
from IPython.display import display
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots

# %% [markdown]
# Acostumbraros a realizar siempre estas 3 comprobaciones del df

# %%
df = pd.read_excel("/Users/carlosoliver/Desktop/BOOTCAMP/DataScience-Mar2024/2-Data_Analysis/4-Visualización/3-Plotly/Ejercicios/data/Sample - Superstore.xlsx")

# %%
df.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                           9994                           9994
# mean   2016-04-30 00:07:12.259355648  2016-05-03 23:06:58.571142912
# min              2014-01-03 00:00:00            2014-01-07 00:00:00
# 25%              2015-05-23 00:00:00            2015-05-27 00:00:00
# 50%              2016-06-26 00:00:00            2016-06-29 00:00:00
# 75%              2017-05-14 00:00:00            2017-05-18 00:00:00
# max              2017-12-30 00:00:00            2018-01-05 00:00:00
# std                              NaN                            NaN
#
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# ...

# %% [markdown]
# ## 1. Create an interactive bar chart showing total sales by State for2014.

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
Df_2014 = df[df["Order Date"].dt.year == 2014]
Df_2014
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 5     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...              ...        ...        ...             ...         ...
# 9946  CA-2014-111157 2014-03-02 2014-03-06  Standard Class    NH-18610
# 9956  US-2014-143287 2014-11-11 2014-11-17  Standard Class    KN-16705
# 9957  US-2014-143287 2014-11-11 2014-11-17  Standard Class    KN-16705
# 9958  US-2014-143287 2014-11-11 2014-11-17  Standard Class    KN-16705
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
#
#          Customer Name      Segment        Country          City  \
# ...

# %%
# Filter the DataFrame for the year 2014
df_2014 = df[df['Order Date'].dt.year == 2014]

# Group and aggregate data
sales_by_state = df_2014.groupby('State')['Sales'].sum().reset_index().sort_values(by='Sales', ascending=False)

# Create interactive bar chart using Plotly
fig = px.bar(sales_by_state, x='State', y='Sales', 
             labels={'Sales': 'Total Sales', 'State': 'State'}, 
             title='Total Sales by State for the Year 2014',
             color='State')  # Color bars by state for better differentiation

# Show the interactive chart
fig.show()

# %% [markdown]
# ## 2. Create an interactive line chart showing Sales and Profit in 2014.

# %%
data_grouped_by_date = df.groupby('Order Date').agg({'Sales':'sum', 'Profit':'sum'}).reset_index()
# Genera un data frame con las columnas order y las sumas de sales y profit
data_grouped_by_date
# Crea un figura de graficas vacias
fig = go.Figure()

# Se agregan a la grafica vacia la reclacion fechas y ventas
fig.add_trace(go.Scatter(x=data_grouped_by_date['Order Date'], y=data_grouped_by_date['Sales'],
                         mode='lines', name='Sales'))

# Se agregan a la grafica vacia la reclacion fechas y profit
fig.add_trace(go.Scatter(x=data_grouped_by_date['Order Date'], y=data_grouped_by_date['Profit'],
                         mode='lines', name='Profit'))
# Actualiza las graficas con los titulos
fig.update_layout(title='Sales and Profit in 2014',
                  xaxis_title='Order Date',
                  yaxis_title='Amount')
fig.show()

# %% [markdown]
# ## 3. Create a set of 3 interactive histograms showing the distributions of quantity per order for the following states: California, New York and Texas.

# %%
fig1.update_layout(title='Distribution of Quantity per Order in California',
                   xaxis_title='Quantity',
                   yaxis_title='Count')
fig2.update_layout(title='Distribution of Quantity per Order in New York',
                   xaxis_title='Quantity',
                   yaxis_title='Count')
fig3.update_layout(title='Distribution of Quantity per Order in Texas',
                   xaxis_title='Quantity',
                   yaxis_title='Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 fig1.update_layout(title='Distribution of Quantity per Order in California',
#       2                    xaxis_title='Quantity',
#       3                    yaxis_title='Count')
#       4 fig2.update_layout(title='Distribution of Quantity per Order in New York',
#       5                    xaxis_title='Quantity',
#       6                    yaxis_title='Count')
#       7 fig3.update_layout(title='Distribution of Quantity per Order in Texas',
#       8                    xaxis_title='Quantity',
#       9                    yaxis_title='Count')
#
# NameError: name 'fig1' is not defined

# %%
# Mascaras para ciudades
california_data = df[df['State'] == 'California']
new_york_data = df[df['State'] == 'New York']
texas_data = df[df['State'] == 'Texas']
fig = make_subplots(rows=1, cols=3, subplot_titles=('California', 'New York', 'Texas'))

#Crear graficos
fig1 = go.Figure(data=[go.Histogram(x=california_data['Quantity'], name='California')], row=1, col=1)
fig2 = go.Figure(data=[go.Histogram(x=new_york_data['Quantity'], name='New York')],row=1, col=2)
fig3 = go.Figure(data=[go.Histogram(x=texas_data['Quantity'], name='Texas')], row=1, col=3)

ply.data[fig1,fig2,fig3]

fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 8
#       5 fig = make_subplots(rows=1, cols=3, subplot_titles=('California', 'New York', 'Texas'))
#       7 #Crear graficos
# ----> 8 fig1 = go.Figure(data=[go.Histogram(x=california_data['Quantity'], name='California')], row=1, col=1)
#       9 fig2 = go.Figure(data=[go.Histogram(x=new_york_data['Quantity'], name='New York')],row=1, col=2)
#      10 fig3 = go.Figure(data=[go.Histogram(x=texas_data['Quantity'], name='Texas')], row=1, col=3)
#
# File ~/miniconda3/envs/EDA_ENV/lib/python3.10/site-packages/plotly/graph_objs/_figure.py:633, in Figure.__init__(self, data, layout, frames, skip_invalid, **kwargs)
#       5 def __init__(
#       6     self, data=None, layout=None, frames=None, skip_invalid=False, **kwargs
#       7 ):
#       8     """
#       9     Create a new :class:Figure instance
#      10
# ...

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Assuming 'df' is your DataFrame after reading from a CSV or other data source

# Filter the DataFrame for the states California, New York, and Texas
df_california = df[df['State'] == 'California']
df_new_york = df[df['State'] == 'New York']
df_texas = df[df['State'] == 'Texas']

# Create a subplot with 1 row and 3 columns
fig = make_subplots(rows=1, cols=3, subplot_titles=('California', 'New York', 'Texas'))

# Add a histogram to each subplot for the corresponding state
fig.add_trace(go.Histogram(x=df_california['Quantity'], name='California'), row=1, col=1)
fig.add_trace(go.Histogram(x=df_new_york['Quantity'], name='New York'), row=1, col=2)
fig.add_trace(go.Histogram(x=df_texas['Quantity'], name='Texas'), row=1, col=3)

# Update the layout of the figure
fig.update_layout(title_text='Quantity per order in 3 States', showlegend=False)
fig.update_xaxes(title_text='Quantity')
fig.update_yaxes(title_text='Count')

# Show the figure
fig.show()

# %% [markdown]
# ## 4. Create an interactive stacked bar chart showing the revenue by state (bars) for each of the products categories for California, New York and Texas.

# %%
# Out:
#         State         Category        Sales
# 0  California        Furniture  156064.6015
# 1  California  Office Supplies  142351.9480
# 2  California       Technology  159271.0820
# 3    New York        Furniture   93372.7290
# 4    New York  Office Supplies   90020.0420
# 5    New York       Technology  127483.5000
# 6       Texas        Furniture   60593.2918
# 7       Texas  Office Supplies   44490.5300
# 8       Texas       Technology   65104.2240

# %%
# Out:
# <div>                            <div id="d21dd30f-3b13-48c4-b1b8-dab1cdcc436b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d21dd30f-3b13-48c4-b1b8-dab1cdcc436b")) {                    Plotly.newPlot(                        "d21dd30f-3b13-48c4-b1b8-dab1cdcc436b",                        [{"alignmentgroup":"True","hovertemplate":"State=California<br>Category=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"California","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"California","offsetgroup":"California","orientation":"v","showlegend":true,"textposition":"auto","x":["Furniture","Office Supplies","Technology"],"xaxis":"x","y":[156064.60150000002,142351.948,159271.082],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"S
# ...

# %%
import plotly.express as px

# Filtrar los datos para incluir solo los estados de California, Nueva York y Texas
filtered_df = df[df['State'].isin(['California', 'New York', 'Texas'])].groupby(['State', 'Category'], as_index= False)[['Sales']].sum()

ventas_por_categoria = filtered_df.groupby('Category')['Sales'].sum().reset_index()


# Crear el gráfico de barras interactivo con Plotly Express
fig = px.bar(filtered_df, x='Category', y='Sales', color='State',
             labels={'Sales': 'Total Sales', 'Category': 'Category'},
             title='Total Sales by Category for California, New York, and Texas')

# Mostrar el gráfico interactivo
fig.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 10
#       7 ventas_por_categoria = filtered_df.groupby('State')['Sales'].sum().reset_index()
#       9 # Crear el gráfico de barras interactivo con Plotly Express
# ---> 10 fig = px.bar(ventas_por_categoria, x='Category', y='Sales',
#      11              labels={'Sales': 'Total Sales', 'Category': 'Category'},
#      12              title='Total Sales by Category for California, New York, and Texas')
#      14 # Mostrar el gráfico interactivo
#      15 fig.show()
#
# ...

# %%
import plotly.express as px

# Filtrar los datos para incluir solo los estados de California, Nueva York y Texas
filtered_df = df[df['State'].isin(['California', 'New York', 'Texas'])]

# Sumar las ventas por categoría y ciudad
ventas_por_categoria_y_ciudad = filtered_df.groupby(['Category', 'City'])['Sales'].sum().reset_index()

# Crear el gráfico de barras interactivo con Plotly Express
fig = px.bar(ventas_por_categoria_y_ciudad, x='Category', y='Sales',
             facet_row='City', color='City', facet_row_spacing=0.03,
             labels={'Sales': 'Total Sales', 'Category': 'Category'},
             title='Total Sales by Category for California, New York, and Texas (Faceted by City)')

# Mostrar el gráfico interactivo
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 10
#       7 ventas_por_categoria_y_ciudad = filtered_df.groupby(['Category', 'City'])['Sales'].sum().reset_index()
#       9 # Crear el gráfico de barras interactivo con Plotly Express
# ---> 10 fig = px.bar(ventas_por_categoria_y_ciudad, x='Category', y='Sales',
#      11              facet_row='City', color='City', facet_row_spacing=0.03,
#      12              labels={'Sales': 'Total Sales', 'Category': 'Category'},
#      13              title='Total Sales by Category for California, New York, and Texas (Faceted by City)')
#      15 # Mostrar el gráfico interactivo
#      16 fig.show()
#
# ...

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %% [markdown]
# ## 5. Create an interactive line chart showing sale by day for California.

# %%
# Out:
#                Sales
# Order Date
# 2014-01-06    19.440
# 2014-01-13  1679.749
# 2014-01-20    38.660
# 2014-01-27   426.670
# 2014-01-31   290.666

# %%
# Out:
# <div>                            <div id="b3a855e1-17b8-42df-9a7b-581e0c3c2e00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3a855e1-17b8-42df-9a7b-581e0c3c2e00")) {                    Plotly.newPlot(                        "b3a855e1-17b8-42df-9a7b-581e0c3c2e00",                        [{"mode":"lines","x":["2014-01-06T00:00:00","2014-01-13T00:00:00","2014-01-20T00:00:00","2014-01-27T00:00:00","2014-01-31T00:00:00","2014-02-02T00:00:00","2014-02-04T00:00:00","2014-02-12T00:00:00","2014-02-20T00:00:00","2014-02-22T00:00:00","2014-03-03T00:00:00","2014-03-11T00:00:00","2014-03-14T00:00:00","2014-03-18T00:00:00","2014-03-23T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-30T00:00:00","2014-03-31T00:00:00","2014-
# ...

# %%
filtered_df = df[df['Order date'].isin(['California', 'New York', 'Texas'])]

# %%
import plotly.express as px

# Filtrar los datos para incluir solo las filas correspondientes a California
california_data = df[df['State'] == 'California']

# Agrupar los datos por día y sumar las ventas para cada día
sales_by_day = california_data.groupby('Order Date')['Sales'].sum().reset_index()

# Crear el gráfico de línea interactivo con Plotly Express
fig = px.line(sales_by_day, x='Order Date', y='Sales', title='Sales by Day in California')
fig.update_xaxes(title='Date')
fig.update_yaxes(title='Sales')

# Mostrar el gráfico interactivo
fig.show()

# %%
import plotly.graph_objs as go

filtro5 = df[["Order Date", "Sales"]]
trace1 = go.Scatter(
    x=filtro5["Order Date"],
    y=filtro5["Sales"],
    name='citations',
    mode='lines'
)

fig = go.Figure(trace1)

# Mostrar el gráfico en una ventana emergente
fig.show()
