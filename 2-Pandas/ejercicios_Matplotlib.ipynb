# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 2. Activa matplotlib de forma estática

# %%
# %matplotlib inline

# %% [markdown]
# 3. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.

# %%
x = np.linspace(0,5, 100)
y1 = 3*x+0
y2 = -3*x-5

# %%
x = np.linspace(0,5, 100)
y1 = 3*x+0
y2 = -3*x-5
plt.subplot(1, 2, 1)
plt.plot(x,y1)
plt.subplot(1, 2, 2)
plt.plot(x, y2)

# %% [markdown]
# 4. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
x = np.linspace(0, 5, 100)
y = np.linspace(-15, 15, 100)

# %% [markdown]
# 5. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
x = np.linspace(0, 15, 100)
y = np.linspace(-5, 4, 100)

y1 = 3*x+0
y2 = -3*x-5

# %%
plt.subplot(1,2,1)
plt.plot(y1)
plt.title("Recta sube")
plt.xlabel("Eje X")
plt.subplot(1,2,2)
plt.plot(y2)
plt.title("Recta baja")
plt.xlabel("Eje Y")
# Out:
# Text(0.5, 0, 'Eje Y')

# %% [markdown]
# Vamos a pintar lo mismo pero accediendo directamente a los ejes

# %% [markdown]
# 6. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
x = np.linspace(0,5, 100)
y1 = 3*x+0
y2 = -3*x-5
plt.subplot(1, 2, 1)
plt.plot(x,y1)
plt.ylim(0, 15)
plt.xlim(0, 5)
plt.subplot(1, 2, 2)
plt.plot(x, y2)
plt.ylim(-7, -20)
plt.xlim(0, 5)
# Out:
# (0.0, 5.0)

# %%
# Crear valores de ejes X entre 0 y 5
x_values = np.linspace(0, 5, 100)

# Calcular los valores de las rectas
y1_values = 3 * x_values  # Pendiente positiva de 3
y2_values = -3 * x_values - 5  # Pendiente negativa de 3, pasando por (0, -5)

# Crear figura y ejes separados
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Graficar la recta con pendiente positiva en el primer subplot
axs[0].plot(x_values, y1_values, color='blue')
axs[0].set_title('Recta con pendiente positiva (m=3)')
axs[0].set_xlabel('Eje X')
axs[0].set_ylabel('Eje Y')
axs[0].grid(True)

# Graficar la recta con pendiente negativa en el segundo subplot
axs[1].plot(x_values, y2_values, color='red')
axs[1].set_title('Recta con pendiente negativa (m=-3)')
axs[1].set_xlabel('Eje X')
axs[1].set_ylabel('Eje Y')
axs[1].grid(True)

# Ajustar el espaciado entre subplots
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# 7. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
x = [20,22,24,26,28]
y = [5,15,-5,20,5]

plt.bar(x, y, color='skyblue')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 8. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear gráfico de barras
plt.bar(nombres, alturas, color='green')

plt.xlabel('Personas')
plt.ylabel('Altura (cm)')
plt.title('Alturas de un Grupo de Amigos')

# Mostrar gráfico
plt.show()

# %%
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear gráfico de barras
plt.bar(nombres, alturas, color='green')

plt.xlabel('Personas')
plt.ylabel('Altura (cm)')
plt.title('Alturas de un Grupo de Amigos')

# Mostrar gráfico
plt.show()

# %% [markdown]
# 9. Basándote en el gráfico anterior, escribe encima de cada barra la altura de cada amigo.
# Pista: usa un bucle que lea cada barra de barplot = plt.bar(x,y)
# bar tiene los métodos get_height(), get_x(), get_width()
# plt.text(x,y,valor, va='bottom')

# %%
# Datos de alturas y nombres
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear gráfico de barras
plt.bar(nombres, alturas, color='green')

# Agregar etiquetas con las alturas
for i in range(len(nombres)):
    plt.text(i, alturas[i] + 2, str(alturas[i]), ha='center', color='black')

# Etiquetas y título
plt.xlabel('Personas')
plt.ylabel('Altura (cm)')
plt.title('Alturas de un Grupo de Amigos')

# Mostrar gráfico
plt.show()

# %% [markdown]
# 10. Cambia el tamaño de la figura a (3,5)

# %%
# Datos de alturas y nombres
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]
plt.figure(figsize=(3,5))
# Crear gráfico de barras
plt.bar(nombres, alturas, color='green')

# Agregar etiquetas con las alturas
for i in range(len(nombres)):
    plt.text(i, alturas[i] + 2, str(alturas[i]), ha='center', color='black')


# Etiquetas y título
plt.xlabel('Personas')
plt.ylabel('Altura (cm)')
plt.title('Alturas de un Grupo de Amigos')

# Mostrar gráfico
plt.show()

# %% [markdown]
# 11. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
# Datos de alturas y nombres
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]
plt.figure(figsize=(3,5))
# Crear gráfico de barras
plt.bar(nombres, alturas, color='green')

# Agregar etiquetas con las alturas
for i in range(len(nombres)):
    plt.text(i, alturas[i] + 2, str(alturas[i]), ha='center', color='black')

plt.tick_params(axis='y', which='both', left=False, labelleft=False)


# Etiquetas y título
plt.xlabel('Personas')
plt.ylabel('Altura (cm)')
plt.title('Alturas de un Grupo de Amigos')

# Mostrar gráfico
plt.show()

# %% [markdown]
# 12. Prueba a hacer el gráfico con las barras en horizontal (no es necesario poner el texto al final de la barra).

# %%
plt.barh(nombres, alturas, color='green')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 13. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
fig, axs = plt.subplots()
plt.barh(nombres, alturas)
axs.invert_xaxis()

# %% [markdown]
# 14. En el último gráfico, cambia el estilo a 'dark_background'

# %%
plt.style.use("dark_background")
fig, axs = plt.subplots()
plt.barh(nombres, alturas)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 15. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
data = {
    "Year": [2015,2016,2017,2018, 2019],
    "sold_itemsA": [100, 3500, 4000, 5500, 7000]
}

df = pd.DataFrame(data)

# %% [markdown]
# 16. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
plt.style.use("classic")

plt.plot(df.loc[:,"sold_itemsA"], df.loc[:,"Year"], "g--", label = "ffffffffffffff")
plt.legend()
plt.title("Hola")
plt.xlabel("ventas")
plt.ylabel("año")
# Out:
# Text(0, 0.5, 'año')

# %% [markdown]
# 17. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
plt.style.use("classic")

plt.plot(df.loc[:,"sold_itemsA"], df.loc[:,"Year"], "g--", label = "Departamento A")
plt.plot(df.loc[:,"B"], df.loc[:,"Year"], "r:", label = "departamento B")

plt.legend()
plt.title("Hola")
plt.xlabel("ventas")
plt.ylabel("año")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/EDA_ENV/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'B'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 4
#       1 plt.style.use("classic")
#       3 plt.plot(df.loc[:,"sold_itemsA"], df.loc[:,"Year"], "g--", label = "Departamento A")
# ----> 4 plt.plot(df.loc[:,"B"], df.loc[:,"Year"], "r:", label = "departamento B")
#       6 plt.legend()
#       7 plt.title("Hola")
#
# File ~/miniconda3/envs/EDA_ENV/lib/python3.10/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~/miniconda3/envs/EDA_ENV/lib/python3.10/site-packages/pandas/core/indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File ~/miniconda3/envs/EDA_ENV/lib/python3.10/site-packages/pandas/core/indexing.py:1065, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1061 for i, key in enumerate(tup):
#    1062     if is_label_like(key):
#    1063         # We don't need to check for tuples here because those are
#    1064         #  caught by the _is_nested_tuple_indexer check above.
# -> 1065         section = self._getitem_axis(key, axis=i)
#    1067         # We should never have a scalar section here, because
#    1068         #  _getitem_lowerdim is only called after a check for
#    1069         #  is_scalar_access, which that would be.
#    1070         if section.ndim == self.ndim:
#    1071             # we're in the middle of slicing through a MultiIndex
#    1072             # revise the key wrt to `section` by inserting an _NS
#
# File ~/miniconda3/envs/EDA_ENV/lib/python3.10/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/miniconda3/envs/EDA_ENV/lib/python3.10/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/miniconda3/envs/EDA_ENV/lib/python3.10/site-packages/pandas/core/generic.py:4284, in NDFrame.xs(self, key, axis, level, drop_level)
#    4282 if axis == 1:
#    4283     if drop_level:
# -> 4284         return self[key]
#    4285     index = self.columns
#    4286 else:
#
# File ~/miniconda3/envs/EDA_ENV/lib/python3.10/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/miniconda3/envs/EDA_ENV/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'B'

# %% [markdown]
# 18. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
df.plot("sold_itemsA", "Year" ,label = "Departamento A", kind= "scatter" )
# Out:
# <Axes: xlabel='sold_itemsA', ylabel='Year'>

# %% [markdown]
# 19. Prueba a cambiar kind a 'pie'

# %%
df.plot("sold_itemsA", "Year" ,label = "Departamento A", kind= "pie" )
# Out:
# <Axes: ylabel='Departamento A'>

# %% [markdown]
# 20. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
plt.style.use("classic")

plt.plot(df.loc[:,"sold_itemsA"], df.loc[:,"Year"], "g--", label = "Departamento A")
plt.plot(df.loc[:,"B"], df.loc[:,"Year"], "r:", label = "departamento B")

plt.legend = False
plt.title("Hola")
plt.xlabel("ventas")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# 21. Vamos a pintar un histograma

# %%
# Out:
#   Cell In[89], line 1
#     data = {"nombres" = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen'],
#             ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
# Alturas
alturas = [160, 180, 175, 190, 170]

# Crear histograma
plt.hist(alturas, bins=5, color='skyblue', edgecolor='black')

# Establecer el rango del eje y (opcional, dependiendo de tus necesidades)
plt.ylim(0, 70)

# Etiquetas y título
plt.xlabel('Alturas')
plt.ylabel('Frecuencia')
plt.title('Histograma de Alturas')

# Mostrar histograma
plt.show()

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html

# %%
pd.DataFrame({"alturas":np.random.randn(1000)*12+170}).plot(kind="hist", bins=100)
# Out:
# <Axes: ylabel='Frequency'>
